# %%
from __future__ import print_function, division

import os, json, sys
sys.path.append('../..') 

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.utils import save_image


from IPython.display import Image

# %%
plt.ion()   # interactive mode
folder_data = '/media/tiago/tiagobotari/data'

# %%
# Data augmentation and normalization for training
# Just normalization for validation
_image_size = 64
_mean = [0.485, 0.456, 0.406]
_std = [0.229, 0.224, 0.225]

data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.RandomCrop(_image_size),
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(.3, .3, .3),
        transforms.ToTensor(),
        transforms.Normalize(_mean, _std)
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(_image_size),
        transforms.ToTensor(),
        transforms.Normalize(_mean, _std)
    ]),
}

# %%
ants = False
if ants:
    data_dir = '{:}/hymenoptera_data'.format(folder_data)
    image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                              data_transforms[x])
                      for x in ['train', 'val']}
    dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size,
                                                 shuffle=True, num_workers=4)
                  for x in ['train', 'val']}
    dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
    class_names = image_datasets['train'].classes

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    device

    data_loader = dataloaders['train']

# %%
batch_size = 144
data_dir = '{:}/dogscats'.format(folder_data)
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device

data_loader = dataloaders['train']

# %% [markdown]
# ### Visualize

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updateda

# %%
# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)
print([class_names[x] for x in classes])
imshow(out )
# Out:
# ['dogs', 'cats', 'cats', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'cats', 'cats', 'cats', 'dogs', 'cats', 'cats', 'dogs', 'dogs', 'cats', 'dogs', 'cats', 'cats', 'cats', 'dogs', 'cats', 'cats', 'cats', 'cats', 'cats', 'dogs', 'cats', 'cats', 'cats', 'dogs', 'dogs', 'cats', 'dogs', 'cats', 'dogs', 'dogs', 'cats', 'cats', 'dogs', 'cats', 'cats', 'dogs', 'dogs', 'dogs', 'cats', 'dogs', 'cats', 'dogs', 'cats', 'cats', 'dogs', 'dogs', 'dogs', 'dogs', 'cats', 'dogs', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'dogs', 'dogs', 'dogs', 'cats', 'dogs', 'cats', 'dogs', 'dogs', 'cats', 'cats', 'dogs', 'cats', 'dogs', 'dogs', 'cats', 'dogs', 'dogs', 'cats', 'dogs', 'cats', 'dogs', 'dogs', 'cats', 'dogs', 'dogs', 'cats', 'dogs', 'cats', 'dogs', 'dogs', 'cats', 'dogs', 'cats', 'dogs', 'cats', 'cats', 'cats', 'dogs', 'dogs', 'cats', 'dogs', 'dogs', 'cats', 'cats', 'dogs', 'dogs', 'cats', 'dogs', 'cats', 'cats', 'dogs', 'cats', 'dogs', 'cats', 'cats', 'cats', 'dogs', 'cats', 'dogs', 'dogs', 'dogs', 'cats', 'cats', 'dogs', 'cats', 'dogs', 'dogs', 'cats', 'cats', 'dogs', 'cats', 'dogs', 'dogs', 'dogs', 'cats', 'dogs', 'dogs', 'cats', 'dogs']

# %%
# # Load MNIST Data
# dataset = datasets.MNIST(root=folder_data, train=True, transform=transforms.ToTensor(), download=False)
# data_loader = torch.utils.data.DataLoader(dataset, batch_size=bs, shuffle=True)

# %%
# Fixed input for debugging
fixed_x, _ = next(iter(data_loader))
fixed_x = fixed_x.to(device)
print(fixed_x.size())
# save_image(fixed_x)
# fixed_x = flatten(fixed_x)

Image('real_image.png')
# Out:
# torch.Size([144, 3, 64, 64])

# %% [markdown]
# # VAE CNN

# %%
def save_image(x, path='real_image.png'):
    torchvision.utils.save_image(x, path)
def flatten(x):
    return to_var(x.view(x.size(0), -1))
def to_var(x):
    if torch.cuda.is_available():
        x = x.cuda()
    return Variable(x)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
# from density_lime.densities.density_cvae import VAE

class VAE(nn.Module):
    def __init__(self, image_channels=3, kernel_size=3, stride=1, nodes_dim=1024, latent_dim=32):
        super().__init__()
        
        self.nodes_dim = nodes_dim
        self.latent_dim = latent_dim
        self.chanels = [32, 64, 128, 256, 512]
        # Encoder
        self.layers_encoder = nn.ModuleList(self.create_layers_encoder(image_channels=image_channels)) 
    
         # Mu and log_var
        self.fc_mu = nn.Linear(self.nodes_dim, self.latent_dim)
        self.fc_log_var = nn.Linear(self.nodes_dim, self.latent_dim)
        
        self.fc_out = nn.Linear(self.latent_dim, self.chanels[-1]*4)
        
        # Decoder
        self.layers_decoder = nn.ModuleList(
            self.create_layers_decoder(
                nodes_dim=self.nodes_dim, image_channels=image_channels
            )
        )
        
        self.output = nn.Identity()
    def encode(self, x):
        x_in = x
        for layer in self.layers_encoder:
            # TODO: doubt!! no functional here, not sure what is the best option
            print('decode out size: ', x_in.size())
            x_in = layer(x_in)
        return x_in

    def decode(self, z):
        x_in = z
        for layer in self.layers_decoder:
            # TODO: doubt!! no functional here, not sure what is the best option
            print('decode out size: ', x_in.size())
            x_in = layer(x_in)
        return x_in
            
    @staticmethod
    def reparameterize(mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps*std    
    
    def forward(self, x):
        x_enconde = self.encode(x)
        x_enconde = x_enconde.view(-1, self.nodes_dim)
        mu, log_var = self.fc_mu(x_enconde), self.fc_log_var(x_enconde)
        z = self.reparameterize(mu, log_var)
        z = self.fc_out(z)
        z = z.view(-1, 512, 2, 2)
        x_out = self.decode(z)
        return x_out, mu, log_var
    
    def create_layers_encoder(self, image_channels):
        # TODO: Would be nice to have some options here.
        # TODO: doubt!!! I choose to use the Elu layer here. not sure about this.
        # TODO: I am thinking to put a batch normalization between the layers.
        out_chanels = self.chanels
        layers = list()
        for out_chanel in out_chanels:
            layers.append(
                nn.Sequential(
                nn.Conv2d(image_channels, out_chanel, kernel_size=3, stride=2, padding=1)
                , nn.BatchNorm2d(out_chanel)
                , nn.LeakyReLU()   
                )
            )
            image_channels = out_chanel
        return layers
    
    def create_layers_decoder(self, nodes_dim, image_channels):
        # TODO: Would be nice to have some options here.
        # TODO: doubt!!! I choose to use the Elu layer here. not sure about this.
        # TODO: I am thinking to put a batch normalization between the layers.
        out_chanels = self.chanels
        out_chanels.reverse()
        print(out_chanels)
        print(out_chanels[:-2])
        layers = list()
        for in_chanel, out_chanel in zip(out_chanels[:-1], out_chanels[1:]) :
            layers.append(
                nn.Sequential(
                 nn.ConvTranspose2d(
                     in_chanel, out_chanel, kernel_size=3, stride=2, padding=1, output_padding=1)
                , nn.BatchNorm2d(out_chanel)
                , nn.LeakyReLU()   
                )
            )
                
        layers.append(
            nn.Sequential(
                            nn.ConvTranspose2d(out_chanels[-1],
                                               out_chanels[-1],
                                               kernel_size=3,
                                               stride=2,
                                               padding=1,
                                               output_padding=1),
                            nn.BatchNorm2d(out_chanels[-1]),
                            nn.LeakyReLU(),
                            nn.Conv2d(out_chanels[-1], out_channels=3,
                                      kernel_size=3, padding=1),
                            nn.Tanh()
            )
        )
        return layers
                
#                 layers = [
# #             nn.BatchNorm2d(nodes_dim, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             , nn.ConvTranspose2d(nodes_dim, 128, kernel_size=4, stride=1)
#             , nn.BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             , nn.ELU()
#             , nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2)
#             , nn.BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             , nn.ELU()
#             , nn.ConvTranspose2d(64, 32, kernel_size=4, stride=1)
#             , nn.BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             , nn.ELU()
#             , nn.ConvTranspose2d(32, image_channels, kernel_size=4, stride=2)
#             , nn.Sigmoid()  # TODO: should I include this?
#         ]
#         #         self.d8 = 
#         return layers

# %%
image_channels = 3
vae = VAE(image_channels=image_channels, nodes_dim=256, latent_dim=256)
if torch.cuda.is_available():
    vae.cuda()
vae
# Out:
# [512, 256, 128, 64, 32]
# [512, 256, 128]
# VAE(
#   (layers_encoder): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (fc_mu): Linear(in_features=256, out_features=256, bias=True)
#   (fc_log_var): Linear(in_features=256, out_features=256, bias=True)
#   (fc_out): Linear(in_features=256, out_features=2048, bias=True)
#   (layers_decoder): ModuleList(
#     (0): Sequential(
#       (0): ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (2): Sequential(
#       (0): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (3): Sequential(
#       (0): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (4): Sequential(
#       (0): ConvTranspose2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): Tanh()
#     )
#   )
#   (output): Identity()
# )

# %%
optimizer = torch.optim.Adam(vae.parameters(), lr=1e-3)

# %%
def loss_fn(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x, size_average=False)

    # see Appendix B from VAE paper:
    # Kingma and Welling. Auto-Encoding Variational Bayes. ICLR, 2014
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD = -0.5 * torch.sum(1 + logvar - mu**2 -  logvar.exp())
    return BCE + KLD

# %%
Hin = 5
padding=1
output_padding = 0
dilation=1
kernel_size=6
stride=2 
print('CNN', (Hin + 2*padding - dilation *(kernel_size-1)-1)/stride + 1)
print('CNN T', (Hin-1)*stride - 2*padding+dilation*(kernel_size-1) + output_padding + 1 )
# Out:
# CNN 1.5
# CNN T 12

# %%
epochs = 300
for epoch in range(epochs):
    for idx, (images, _) in enumerate(data_loader):
#         images = flatten(images)
        images = images.to(device)
        recon_images, mu, logvar = vae(images)
        loss = loss_fn(recon_images, images, mu, logvar)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
                
    print("Epoch[{}/{}] Loss: {:.3f}".format(epoch+1, epochs, loss.data.item()/batch_size))

    recon_x, _, _ = vae(fixed_x)
    print('>>>>>>>>>>>>>>>>>>>>>>')
    save_image(
        recon_x.view(
            recon_x.size(0), image_channels, 28, 28).data.cpu(), f'/media/tiago/tiagobotari/reco/i_{epoch}_{idx}.png')
    print('#####################################')
# Out:
# decode out size:  torch.Size([1024, 512, 2, 2])
# decode out size:  torch.Size([1024, 256, 4, 4])
# decode out size:  torch.Size([1024, 128, 8, 8])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-100-be148ce047a7> in <module>
#       4 #         images = flatten(images)
#       5         images = images.to(device)
# ----> 6         recon_images, mu, logvar = vae(images)
#       7         loss = loss_fn(recon_images, images, mu, logvar)
#       8
#
# ~/anaconda3/envs/density-lime3.7/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
# --> 550             if hook_result is not None:
#     551                 result = hook_result
#     552         if len(self._backward_hooks) > 0:
#
# <ipython-input-95-af94c1a064e7> in forward(self, x)
#      57         z = self.fc_out(z)
#      58         z = z.view(-1, 512, 2, 2)
# ---> 59         x_out = self.decode(z)
#      60         return x_out, mu, log_var
#      61
#
# <ipython-input-95-af94c1a064e7> in decode(self, z)
#      41             # TODO: doubt!! no functional here, not sure what is the best option
#      42             print('decode out size: ', x_in.size())
# ---> 43             x_in = layer(x_in)
#      44         return x_in
#      45
#
# ~/anaconda3/envs/density-lime3.7/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
# --> 550             if hook_result is not None:
#     551                 result = hook_result
#     552         if len(self._backward_hooks) > 0:
#
# ~/anaconda3/envs/density-lime3.7/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98
#      99     :class:`~torch.nn.ModuleList` can be indexed like a regular Python list, but
# --> 100     modules it contains are properly registered, and will be visible by all
#     101     :class:`~torch.nn.Module` methods.
#     102
#
# ~/anaconda3/envs/density-lime3.7/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
# --> 550             if hook_result is not None:
#     551                 result = hook_result
#     552         if len(self._backward_hooks) > 0:
#
# ~/anaconda3/envs/density-lime3.7/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input, output_size)
#     787             output_padding, self.groups, self.dilation)
#     788
# --> 789
#     790 class ConvTranspose3d(_ConvTransposeMixin, _ConvNd):
#     791     r"""Applies a 3D transposed convolution operator over an input image composed of several input
#
# RuntimeError: CUDA out of memory. Tried to allocate 32.00 MiB (GPU 0; 10.91 GiB total capacity; 3.81 GiB already allocated; 80.88 MiB free; 3.83 GiB reserved in total by PyTorch)

# %%
epochs = 500
for epoch in range(epochs):
    for idx, (images, _) in enumerate(data_loader):
#         images = flatten(images)
        images = images.to(device)
        recon_images, mu, logvar = vae(images)
        loss = loss_fn(recon_images, images, mu, logvar)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
                
    print("zz Epoch[{}/{}] Loss: {:.3f}".format(epoch+1, epochs, loss.data.item()/batch_size))

    recon_x, _, _ = vae(fixed_x)
    print('>>>>>>>>>>>>>>>>>>>>>>')
    save_image(
        recon_x.view(
            recon_x.size(0), image_channels, 28, 28).data.cpu(), f'/media/tiago/tiagobotari/reco/zi_{epoch}_{idx}.png')
    print('#####################################')
# Out:
# zz Epoch[1/500] Loss: 835.082
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[2/500] Loss: 722.510
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[3/500] Loss: 862.163
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[4/500] Loss: 835.474
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[5/500] Loss: 858.131
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[6/500] Loss: 840.552
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[7/500] Loss: 653.001
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[8/500] Loss: 817.439
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[9/500] Loss: 636.904
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[10/500] Loss: 802.885
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[11/500] Loss: 828.578
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[12/500] Loss: 705.709
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[13/500] Loss: 758.506
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[14/500] Loss: 691.043
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[15/500] Loss: 640.745
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[16/500] Loss: 794.944
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[17/500] Loss: 787.298
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[18/500] Loss: 726.355
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[19/500] Loss: 536.205
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# zz Epoch[20/500] Loss: 761.738
# >>>>>>>>>>>>>>>>>>>>>>
# #####################################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-447b6de6444f> in <module>
#       1 epochs = 500
#       2 for epoch in range(epochs):
# ----> 3     for idx, (images, _) in enumerate(data_loader):
#       4 #         images = flatten(images)
#       5         images = images.to(device)
#
# ~/anaconda3/envs/density-lime3.7/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         index = self._next_index()  # may raise StopIteration
#     346         data = self.dataset_fetcher.fetch(index)  # may raise StopIteration
#     347         if self.pin_memory:
#
# ~/anaconda3/envs/density-lime3.7/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     839         self.tasks_outstanding += 1
#     840         self.send_idx += 1
# --> 841
#     842     def _process_data(self, data):
#     843         self.rcvd_idx += 1
#
# ~/anaconda3/envs/density-lime3.7/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#     806
#     807             if self.dataset_kind == _DatasetKind.Iterable:
# --> 808                 # Check for _IterableDatasetStopIteration
#     809                 if isinstance(data, _utils.worker._IterableDatasetStopIteration):
#     810                     self._shutdown_worker(data.worker_id)
#
# ~/anaconda3/envs/density-lime3.7/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     759         elif self.pin_memory:
#     760             while self.pin_memory_thread.is_alive():
# --> 761                 success, data = self._try_get_data()
#     762                 if success:
#     763                     return data
#
# ~/anaconda3/envs/density-lime3.7/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#     102                 if block:
#     103                     timeout = deadline - time.monotonic()
# --> 104                     if not self._poll(timeout):
#     105                         raise Empty
#     106                 elif not self._poll():
#
# ~/anaconda3/envs/density-lime3.7/lib/python3.7/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# ~/anaconda3/envs/density-lime3.7/lib/python3.7/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# ~/anaconda3/envs/density-lime3.7/lib/python3.7/multiprocessing/connection.py in wait(object_list, timeout)
#     918
#     919             while True:
# --> 920                 ready = selector.select(timeout)
#     921                 if ready:
#     922                     return [key.fileobj for (key, events) in ready]
#
# ~/anaconda3/envs/density-lime3.7/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
examples = enumerate(dataloaders['val'])
batch_idx, (example_data, example_targets) = next(examples)

# %%
x_1 = example_data #.to(density.model.device_cpu).numpy()

# %%
import matplotlib.pyplot as plt
def plot_figure(x_1, y_=0):
#     x_img = x_1.reshape(28, 28)
    x_img = x_1
    x_img_plot = x_img  # .cpu().numpy()
    
    fig, ax1 = plt.subplots(1,1)
    plt.setp(ax1.get_xticklabels(), visible=False)
    plt.setp(ax1.get_yticklabels(), visible=False)
    plt.title(y_)
    cp = ax1.imshow(x_img_plot, interpolation = 'none')
    plt.colorbar(cp)
    plt.show()

# %%
x_1.shape
# Out:
# torch.Size([128, 3, 32, 32])

# %%
out = torchvision.utils.make_grid(x_1)
imshow(out)

# %%
x_explain = x_1[0].numpy()
print(x_explain.shape)

x_explain = x_explain.transpose((1, 2, 0))
print(x_explain.shape)
cp = plot_figure(x_explain)
    
try:
    del output
except:
    pass
torch.cuda.empty_cache()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (3, 32, 32)
# (32, 32, 3)

# %%
# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out)

# %%
x_explain.shape
# Out:
# (32, 32, 3)

# %%
x_explain_flat = x_explain.reshape(-1)
x_explain_flat_back = x_explain_flat.reshape(32, 32, 3)
cp = plot_figure(x_explain_flat_back)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
input_dim = x_explain.reshape(-1).shape[0]
model_vae = ModelVAE(input_dim=input_dim, nodes_dim=400, n_layers=4, latent_dim=120, cuda=True, verbose=False)

# %%
density = DensityVAE(input_dim=input_dim, model=model_vae)

# %%
density.fit(dataloaders['train'], epochs=50)

# %%
x_explain.shape
# Out:
# (32, 32, 3)

# %%
x_sample = density.sample_radius(x_exp=x_explain.reshape(-1, input_dim), r=0.1, n_samples=1, random_state=None)

# %%
x_sample.shape
# Out:
# (1, 3072)

# %%
x_sample = x_sample.reshape(32, 32, 3)
# x_sample = x_sample.transpose((1, 2, 0))
print(x_sample.shape)
cp = plot_figure(x_sample)
# Out:
# (32, 32, 3)

# %%
# torch.Size([128, 3, 32, 32])

# %%
x_imge = x_sample[np.random.choice(128, 1)].reshape(_image_size, _image_size)
import matplotlib.pyplot as plt
# img = sample.view(64, 1, 28, 28)
fig, ax1 = plt.subplots(1,1)
# ax1.imshow(img[50][0], interpolation = 'none')
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax1.get_yticklabels(), visible=False)
ax1.imshow(x_imge, interpolation = 'none')
# ax1.set_title('Digit: {}'.format(y))

# %%
x_sample
# Out:
# array([[0.47396147, 0.5028961 , 0.5727099 , ..., 0.5138335 , 0.47757405,
#         0.4861987 ],
#        [0.510321  , 0.53600496, 0.6083321 , ..., 0.548676  , 0.50908154,
#         0.5192861 ],
#        [0.516676  , 0.54314816, 0.6155932 , ..., 0.5555276 , 0.5147015 ,
#         0.52487075],
#        ...,
#        [0.52230364, 0.5487733 , 0.621329  , ..., 0.5604081 , 0.5192437 ,
#         0.5306852 ],
#        [0.5180254 , 0.5433911 , 0.6166062 , ..., 0.55555844, 0.5143192 ,
#         0.52534026],
#        [0.5093462 , 0.53560597, 0.6078215 , ..., 0.547812  , 0.5078505 ,
#         0.5190145 ]], dtype=float32)

# %%
out = torchvision.utils.make_grid(torch.from_numpy(x_sample))

imshow(out)
